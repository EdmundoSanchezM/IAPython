# %% [markdown]
# # Final

# %% [markdown]
# ##### Proceso general de un algoritmo IA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Prediccion del Potencial de un jugador

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data_fifa.csv')
df.head(4)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
print(df['Age'].isnull().any(), df['Potential'].isnull().any())
# Out:
# False False

# %%
plt.scatter(data=df,x='Age',y='Potential')
plt.xlabel('Age')
plt.ylabel('Potential')
# Out:
# Text(0, 0.5, 'Potential')

# %%
plt.hist2d(data=df,x='Age',y='Potential')
plt.xlabel('Age')
plt.ylabel('Potential')
plt.colorbar()

# %%
# data training: x_train = age, y_train = potential
# data training: x_test = age, y_test = potential

# %% [markdown]
# ## Scikit-Learn

# %%
from sklearn.model_selection import train_test_split

# %%
#dividir
x_train,x_test,y_train,y_test=train_test_split(df['Age'],df['Potential'],test_size = 0.2)
print(x_train,x_test,y_train,y_test)
# Out:
# 7558     29
# 11024    31
# 7538     24
# 17996    19
# 2679     30
#          ..
# 3588     33
# 9044     23
# 257      25
# 4405     28
# 5738     29
# Name: Age, Length: 14565, dtype: int64 10648    28
# 4444     30
# 4845     26
# 9478     31
# 4387     22
#          ..
# 14442    19
# 3242     24
# 14391    18
# 16019    20
# 4787     27
# Name: Age, Length: 3642, dtype: int64 7558     68
# 11024    64
# 7538     73
# 17996    63
# 2679     73
#          ..
# 3588     72
# 9044     71
# 257      84
# 4405     71
# 5738     69
# Name: Potential, Length: 14565, dtype: int64 10648    65
# 4444     71
# 4845     70
# 9478     66
# 4387     77
#          ..
# 14442    79
# 3242     79
# 14391    80
# 16019    69
# 4787     70
# Name: Potential, Length: 3642, dtype: int64

# %%
# seleccionar el modelo
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
import numpy as np
#entrenamiento
print(x_train.shape)
print(y_train.shape)
#Convert Series to ndarray
x_train = np.array(x_train)
y_train = np.array(y_train)
#reshape
x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
print(x_train.shape)
print(y_train.shape)

regression.fit(x_train.reshape(-1, 1),y_train.reshape(-1, 1))
# Out:
# (14565, 1)
# (14565, 1)
# (14565, 1)
# (14565, 1)
# LinearRegression()

# %%
#prediction
#Convert Series to ndarray
x_test = np.array(x_train)
y_test = np.array(y_train)
#reshape
x_test = x_train.reshape(-1, 1)
y_x_test = x_train.reshape(-1, 1)
 = y_train.reshape(-1, 1)
regression.predict(x_test)
